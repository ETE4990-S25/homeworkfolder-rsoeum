# %% [markdown]
# ``` py
#
# !pip install takeHomeTest
# import takeHomeTest
#
# !pip install time
# from time import oneWeek as panic
#
# panic.dump(takeHomeTest)
#
#
# print("Welcome to your take home final!\n")
# ```
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## ------------------------------------------- The Legend of Python --------------------------------------------
# **Lore**
#
# In the Kingdom of Pyrovia, all nations once traded in harmony. But since the Shattering of the Global APIs, the knowledge of currency exchange — locked away in XML scrolls — has scattered across the timelines. These scrolls reside in a mysterious repository known only as floatrates.com.
#
# The High Council of Programmers has summoned you (and only you), young code-wielder, to begin your final trial. It is divided into 2 parts.
# * Quest 1 (50xp): Retrieving the scrolls of time - Threading and Json save and parsing
# * Quest 2 (50xp): Decipher the scrolls - Perform EDA on the data.
#
# ------ ------ ------ ------ Extra credit ------ ------ ------ ------
# * Side Quest 1 (10xp*): Lay down seeds for those that follow - create error logs
# * Side Quest 2 (10xp*): The Quest of reflection  - Use profiling on your code to fully understand it
#
# *any points over 100% will be rolled over into your final grade.
#
# I may not have time to run all of your code so make sure you very clearly take notes and communicate successes, issues, and lessons learned.
# Please stay off Chat GPT and stack overflow (and like). You should have most everything you need in the notes.

# %% [markdown]
# --------------------------------------------
# # Quest 1 (50 xp): Retrieving the Scrolls of Time
# Retrieve historical exchange rate data from floatrates.com for one of the (Ideally randomly pick) 52 available currencies, starting from the first record on May 4, 2011, until the present day.
#
# - You may store the data as-is in XML, or convert it to JSON, you may use the supplied code below as a starter.
#
# - Organize each currency into its own directory.
#
# - Ensure your code is modular, maintainable, and robust against timeouts or malformed entries.
#
# ## Notes from the Grand Master
# * Threading is your ally. But do not burn out your ally as they have limited resources. You may use the threading or multi-core to parallelize downloads — but mind the server’s load. Around 10 threads is wise.
#     - You should have around 5040 queries.
#
# * XML Scrolls is a new and unfamiliar beast. Therefore takeing on this beast will wield 5 extra experience points. You will not be penalized for choosing to use JSON
#
# *  Use the Save. Nothing is worse than losing experience you have already gained. Save the raw XML (or converted JSON) using timestamped (in my example below) files so you do not need to look it up again. Ie. If you put in a start date and your program has already read that data it should not pull that date again. (it would be a good idea to delete your data and run it top to bottom before final submission)
#
# * Design gracefully. Structure your project with clear modules: downloader.py, parser.py, and so on.
#
# * Log your quest progress in your quest book to show the Grand Master what you learned this is very important.

# %% [markdown]
# --------------------------------------------

# %%
# !pip install xmltodict
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\rvsoe\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: xmltodict in c:\users\rvsoe\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (0.14.2)

# %%
rates = ["EUR", "GBP", "USD", "DZD", "AUD", "BWP", "BND", "CAD", "CLP", "CNY", "COP", "CZK", "DKK", "HUF", "ISK", "INR", "IDR", "ILS", "KZT", "KRW", "KWD", "LYD", "MYR", "MUR", "NPR", "NZD", "NOK", "OMR", "PKR", "PLN", "QAR", "RUB", "SAR", "SGD", "ZAR", "LKR", "SEK", "CHF", "THB", "TTD"]
ratesForBase = [r for r in rates if r != "USD" and r != "EUR" and r != "GBP"]

# %%
import requests
import xmltodict
import json
import random

# URL of the XML data
date = "2011-05-04"
base = random.choice(ratesForBase)
url = f"https://www.floatrates.com/historical-exchange-rates.html?operation=rates&pb_id=1775&page=historical&currency_date={date}&base_currency_code={base}&format_type=xml"
print(url)
# Fetch the XML data
response = requests.get(url)
response.raise_for_status()  # Ensure we notice bad responses

# Parse the XML data to a Python dictionary
data_dict = xmltodict.parse(response.text)

# Convert the dictionary to a JSON string
json_data = json.dumps(data_dict, indent=4)

# Print the JSON data
print(json_data)

# Optionally, write the JSON data to a file
with open(f"{date}_exchange_rates_{base}.json", "w") as json_file:
    json_file.write(json_data)
# Out:
# https://www.floatrates.com/historical-exchange-rates.html?operation=rates&pb_id=1775&page=historical&currency_date=2011-05-04&base_currency_code=CZK&format_type=xml
# {
#     "channel": {
#         "title": "XML Historical Foreign Exchange Rates for Czech Koruna (CZK) (4 May 2011)",
#         "link": "http://www.floatrates.com/currency/czk/",
#         "xmlLink": "http://www.floatrates.com/daily/czk.xml",
#         "description": "XML historical foreign exchange rates for Czech Koruna (CZK) from the Float Rates. Published at 4 May 2011.",
#         "language": "en",
#         "baseCurrency": "CZK",
#         "pubDate": "Wed, 4 May 2011",
#         "lastBuildDate": "Wed, 4 May 2011",
#         "item": [
#             {
#                 "title": "1 CZK = 0.041311 EUR",
#                 "link": "http://www.floatrates.com/czk/eur/",
#                 "description": "1 Czech Koruna = 0.041311 Euro",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "EUR",
#                 "targetName": "Euro",
#                 "exchangeRate": "0.041311",
#                 "inverseRate": "24.206715",
#                 "inverseDescription": "1 Euro = 24.206715 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.037214 GBP",
#                 "link": "http://www.floatrates.com/czk/gbp/",
#                 "description": "1 Czech Koruna = 0.037214 U.K. Pound Sterling",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "GBP",
#                 "targetName": "U.K. Pound Sterling",
#                 "exchangeRate": "0.037214",
#                 "inverseRate": "26.871789",
#                 "inverseDescription": "1 U.K. Pound Sterling = 26.871789 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.061479 USD",
#                 "link": "http://www.floatrates.com/czk/usd/",
#                 "description": "1 Czech Koruna = 0.061479 U.S. Dollar",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "USD",
#                 "targetName": "U.S. Dollar",
#                 "exchangeRate": "0.061479",
#                 "inverseRate": "16.265768",
#                 "inverseDescription": "1 U.S. Dollar = 16.265768 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 4.383009 DZD",
#                 "link": "http://www.floatrates.com/czk/dzd/",
#                 "description": "1 Czech Koruna = 4.383009 Algerian Dinar",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "DZD",
#                 "targetName": "Algerian Dinar",
#                 "exchangeRate": "4.383009",
#                 "inverseRate": "0.228154",
#                 "inverseDescription": "1 Algerian Dinar = 0.228154 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.056751 AUD",
#                 "link": "http://www.floatrates.com/czk/aud/",
#                 "description": "1 Czech Koruna = 0.056751 Australian Dollar",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "AUD",
#                 "targetName": "Australian Dollar",
#                 "exchangeRate": "0.056751",
#                 "inverseRate": "17.620922",
#                 "inverseDescription": "1 Australian Dollar = 17.620922 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.391834 BWP",
#                 "link": "http://www.floatrates.com/czk/bwp/",
#                 "description": "1 Czech Koruna = 0.391834 Botswana Pula",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "BWP",
#                 "targetName": "Botswana Pula",
#                 "exchangeRate": "0.391834",
#                 "inverseRate": "2.552099",
#                 "inverseDescription": "1 Botswana Pula = 2.552099 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.075631 BND",
#                 "link": "http://www.floatrates.com/czk/bnd/",
#                 "description": "1 Czech Koruna = 0.075631 Brunei Dollar",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "BND",
#                 "targetName": "Brunei Dollar",
#                 "exchangeRate": "0.075631",
#                 "inverseRate": "13.222051",
#                 "inverseDescription": "1 Brunei Dollar = 13.222051 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.058784 CAD",
#                 "link": "http://www.floatrates.com/czk/cad/",
#                 "description": "1 Czech Koruna = 0.058784 Canadian Dollar",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "CAD",
#                 "targetName": "Canadian Dollar",
#                 "exchangeRate": "0.058784",
#                 "inverseRate": "17.011477",
#                 "inverseDescription": "1 Canadian Dollar = 17.011477 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 28.468992 CLP",
#                 "link": "http://www.floatrates.com/czk/clp/",
#                 "description": "1 Czech Koruna = 28.468992 Chilean Peso",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "CLP",
#                 "targetName": "Chilean Peso",
#                 "exchangeRate": "28.468992",
#                 "inverseRate": "0.035126",
#                 "inverseDescription": "1 Chilean Peso = 0.035126 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.399532 CNY",
#                 "link": "http://www.floatrates.com/czk/cny/",
#                 "description": "1 Czech Koruna = 0.399532 Chinese Yuan",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "CNY",
#                 "targetName": "Chinese Yuan",
#                 "exchangeRate": "0.399532",
#                 "inverseRate": "2.502929",
#                 "inverseDescription": "1 Chinese Yuan = 2.502929 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 108.636127 COP",
#                 "link": "http://www.floatrates.com/czk/cop/",
#                 "description": "1 Czech Koruna = 108.636127 Colombian Peso",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "COP",
#                 "targetName": "Colombian Peso",
#                 "exchangeRate": "108.636127",
#                 "inverseRate": "0.009205",
#                 "inverseDescription": "1 Colombian Peso = 0.009205 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 1.000000 CZK",
#                 "link": "http://www.floatrates.com/czk/czk/",
#                 "description": "1 Czech Koruna = 1.000000 Czech Koruna",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "CZK",
#                 "targetName": "Czech Koruna",
#                 "exchangeRate": "1.000000",
#                 "inverseRate": "1.000000",
#                 "inverseDescription": "1 Czech Koruna = 1.000000 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.308046 DKK",
#                 "link": "http://www.floatrates.com/czk/dkk/",
#                 "description": "1 Czech Koruna = 0.308046 Danish Krone",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "DKK",
#                 "targetName": "Danish Krone",
#                 "exchangeRate": "0.308046",
#                 "inverseRate": "3.246268",
#                 "inverseDescription": "1 Danish Krone = 3.246268 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 10.963566 HUF",
#                 "link": "http://www.floatrates.com/czk/huf/",
#                 "description": "1 Czech Koruna = 10.963566 Hungarian Forint",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "HUF",
#                 "targetName": "Hungarian Forint",
#                 "exchangeRate": "10.963566",
#                 "inverseRate": "0.091211",
#                 "inverseDescription": "1 Hungarian Forint = 0.091211 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 6.848124 ISK",
#                 "link": "http://www.floatrates.com/czk/isk/",
#                 "description": "1 Czech Koruna = 6.848124 Icelandic Krona",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "ISK",
#                 "targetName": "Icelandic Krona",
#                 "exchangeRate": "6.848124",
#                 "inverseRate": "0.146025",
#                 "inverseDescription": "1 Icelandic Krona = 0.146025 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 2.738877 INR",
#                 "link": "http://www.floatrates.com/czk/inr/",
#                 "description": "1 Czech Koruna = 2.738877 Indian Rupee",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "INR",
#                 "targetName": "Indian Rupee",
#                 "exchangeRate": "2.738877",
#                 "inverseRate": "0.365113",
#                 "inverseDescription": "1 Indian Rupee = 0.365113 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 526.053302 IDR",
#                 "link": "http://www.floatrates.com/czk/idr/",
#                 "description": "1 Czech Koruna = 526.053302 Indonesian Rupiah",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "IDR",
#                 "targetName": "Indonesian Rupiah",
#                 "exchangeRate": "526.053302",
#                 "inverseRate": "0.001901",
#                 "inverseDescription": "1 Indonesian Rupiah = 0.001901 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.208585 ILS",
#                 "link": "http://www.floatrates.com/czk/ils/",
#                 "description": "1 Czech Koruna = 0.208585 Israeli New Sheqel",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "ILS",
#                 "targetName": "Israeli New Sheqel",
#                 "exchangeRate": "0.208585",
#                 "inverseRate": "4.794216",
#                 "inverseDescription": "1 Israeli New Sheqel = 4.794216 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 8.962995 KZT",
#                 "link": "http://www.floatrates.com/czk/kzt/",
#                 "description": "1 Czech Koruna = 8.962995 Kazakhstani Tenge",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "KZT",
#                 "targetName": "Kazakhstani Tenge",
#                 "exchangeRate": "8.962995",
#                 "inverseRate": "0.111570",
#                 "inverseDescription": "1 Kazakhstani Tenge = 0.111570 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 65.847062 KRW",
#                 "link": "http://www.floatrates.com/czk/krw/",
#                 "description": "1 Czech Koruna = 65.847062 South Korean Won",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "KRW",
#                 "targetName": "South Korean Won",
#                 "exchangeRate": "65.847062",
#                 "inverseRate": "0.015187",
#                 "inverseDescription": "1 South Korean Won = 0.015187 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.016870 KWD",
#                 "link": "http://www.floatrates.com/czk/kwd/",
#                 "description": "1 Czech Koruna = 0.016870 Kuwaiti Dinar",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "KWD",
#                 "targetName": "Kuwaiti Dinar",
#                 "exchangeRate": "0.016870",
#                 "inverseRate": "59.277579",
#                 "inverseDescription": "1 Kuwaiti Dinar = 59.277579 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.118802 LYD",
#                 "link": "http://www.floatrates.com/czk/lyd/",
#                 "description": "1 Czech Koruna = 0.118802 Libyan Dinar",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "LYD",
#                 "targetName": "Libyan Dinar",
#                 "exchangeRate": "0.118802",
#                 "inverseRate": "8.417392",
#                 "inverseDescription": "1 Libyan Dinar = 8.417392 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.183146 MYR",
#                 "link": "http://www.floatrates.com/czk/myr/",
#                 "description": "1 Czech Koruna = 0.183146 Malaysian Ringgit",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "MYR",
#                 "targetName": "Malaysian Ringgit",
#                 "exchangeRate": "0.183146",
#                 "inverseRate": "5.460132",
#                 "inverseDescription": "1 Malaysian Ringgit = 5.460132 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 1.673976 MUR",
#                 "link": "http://www.floatrates.com/czk/mur/",
#                 "description": "1 Czech Koruna = 1.673976 Mauritian Rupee",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "MUR",
#                 "targetName": "Mauritian Rupee",
#                 "exchangeRate": "1.673976",
#                 "inverseRate": "0.597380",
#                 "inverseDescription": "1 Mauritian Rupee = 0.597380 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 4.373602 NPR",
#                 "link": "http://www.floatrates.com/czk/npr/",
#                 "description": "1 Czech Koruna = 4.373602 Nepalese Rupee",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "NPR",
#                 "targetName": "Nepalese Rupee",
#                 "exchangeRate": "4.373602",
#                 "inverseRate": "0.228644",
#                 "inverseDescription": "1 Nepalese Rupee = 0.228644 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.077163 NZD",
#                 "link": "http://www.floatrates.com/czk/nzd/",
#                 "description": "1 Czech Koruna = 0.077163 New Zealand Dollar",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "NZD",
#                 "targetName": "New Zealand Dollar",
#                 "exchangeRate": "0.077163",
#                 "inverseRate": "12.959499",
#                 "inverseDescription": "1 New Zealand Dollar = 12.959499 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.325156 NOK",
#                 "link": "http://www.floatrates.com/czk/nok/",
#                 "description": "1 Czech Koruna = 0.325156 Norwegian Krone",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "NOK",
#                 "targetName": "Norwegian Krone",
#                 "exchangeRate": "0.325156",
#                 "inverseRate": "3.075446",
#                 "inverseDescription": "1 Norwegian Krone = 3.075446 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.023639 OMR",
#                 "link": "http://www.floatrates.com/czk/omr/",
#                 "description": "1 Czech Koruna = 0.023639 Omani Rial",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "OMR",
#                 "targetName": "Omani Rial",
#                 "exchangeRate": "0.023639",
#                 "inverseRate": "42.303687",
#                 "inverseDescription": "1 Omani Rial = 42.303687 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 5.183186 PKR",
#                 "link": "http://www.floatrates.com/czk/pkr/",
#                 "description": "1 Czech Koruna = 5.183186 Pakistani Rupee",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "PKR",
#                 "targetName": "Pakistani Rupee",
#                 "exchangeRate": "5.183186",
#                 "inverseRate": "0.192932",
#                 "inverseDescription": "1 Pakistani Rupee = 0.192932 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.162817 PLN",
#                 "link": "http://www.floatrates.com/czk/pln/",
#                 "description": "1 Czech Koruna = 0.162817 Polish Zloty",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "PLN",
#                 "targetName": "Polish Zloty",
#                 "exchangeRate": "0.162817",
#                 "inverseRate": "6.141881",
#                 "inverseDescription": "1 Polish Zloty = 6.141881 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.223783 QAR",
#                 "link": "http://www.floatrates.com/czk/qar/",
#                 "description": "1 Czech Koruna = 0.223783 Qatari Rial",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "QAR",
#                 "targetName": "Qatari Rial",
#                 "exchangeRate": "0.223783",
#                 "inverseRate": "4.468617",
#                 "inverseDescription": "1 Qatari Rial = 4.468617 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 1.679790 RUB",
#                 "link": "http://www.floatrates.com/czk/rub/",
#                 "description": "1 Czech Koruna = 1.679790 Russian Rouble",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "RUB",
#                 "targetName": "Russian Rouble",
#                 "exchangeRate": "1.679790",
#                 "inverseRate": "0.595312",
#                 "inverseDescription": "1 Russian Rouble = 0.595312 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.230546 SAR",
#                 "link": "http://www.floatrates.com/czk/sar/",
#                 "description": "1 Czech Koruna = 0.230546 Saudi Riyal",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "SAR",
#                 "targetName": "Saudi Riyal",
#                 "exchangeRate": "0.230546",
#                 "inverseRate": "4.337538",
#                 "inverseDescription": "1 Saudi Riyal = 4.337538 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.075572 SGD",
#                 "link": "http://www.floatrates.com/czk/sgd/",
#                 "description": "1 Czech Koruna = 0.075572 Singapore Dollar",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "SGD",
#                 "targetName": "Singapore Dollar",
#                 "exchangeRate": "0.075572",
#                 "inverseRate": "13.232372",
#                 "inverseDescription": "1 Singapore Dollar = 13.232372 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.407230 ZAR",
#                 "link": "http://www.floatrates.com/czk/zar/",
#                 "description": "1 Czech Koruna = 0.407230 South African Rand",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "ZAR",
#                 "targetName": "South African Rand",
#                 "exchangeRate": "0.407230",
#                 "inverseRate": "2.455614",
#                 "inverseDescription": "1 South African Rand = 2.455614 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 6.749236 LKR",
#                 "link": "http://www.floatrates.com/czk/lkr/",
#                 "description": "1 Czech Koruna = 6.749236 Sri Lanka Rupee",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "LKR",
#                 "targetName": "Sri Lanka Rupee",
#                 "exchangeRate": "6.749236",
#                 "inverseRate": "0.148165",
#                 "inverseDescription": "1 Sri Lanka Rupee = 0.148165 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.371529 SEK",
#                 "link": "http://www.floatrates.com/czk/sek/",
#                 "description": "1 Czech Koruna = 0.371529 Swedish Krona",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "SEK",
#                 "targetName": "Swedish Krona",
#                 "exchangeRate": "0.371529",
#                 "inverseRate": "2.691577",
#                 "inverseDescription": "1 Swedish Krona = 2.691577 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.053008 CHF",
#                 "link": "http://www.floatrates.com/czk/chf/",
#                 "description": "1 Czech Koruna = 0.053008 Swiss Franc",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "CHF",
#                 "targetName": "Swiss Franc",
#                 "exchangeRate": "0.053008",
#                 "inverseRate": "18.865084",
#                 "inverseDescription": "1 Swiss Franc = 18.865084 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 1.845835 THB",
#                 "link": "http://www.floatrates.com/czk/thb/",
#                 "description": "1 Czech Koruna = 1.845835 Thai Baht",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "THB",
#                 "targetName": "Thai Baht",
#                 "exchangeRate": "1.845835",
#                 "inverseRate": "0.541760",
#                 "inverseDescription": "1 Thai Baht = 0.541760 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.393163 TTD",
#                 "link": "http://www.floatrates.com/czk/ttd/",
#                 "description": "1 Czech Koruna = 0.393163 Trinidad Tobago Dollar",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "TTD",
#                 "targetName": "Trinidad Tobago Dollar",
#                 "exchangeRate": "0.393163",
#                 "inverseRate": "2.543474",
#                 "inverseDescription": "1 Trinidad Tobago Dollar = 2.543474 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.225781 AED",
#                 "link": "http://www.floatrates.com/czk/aed/",
#                 "description": "1 Czech Koruna = 0.225781 U.A.E Dirham",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "AED",
#                 "targetName": "U.A.E Dirham",
#                 "exchangeRate": "0.225781",
#                 "inverseRate": "4.429072",
#                 "inverseDescription": "1 U.A.E Dirham = 4.429072 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.263701 VEF",
#                 "link": "http://www.floatrates.com/czk/vef/",
#                 "description": "1 Czech Koruna = 0.263701 Venezuelan Bolivar (till 20 August 2018)",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "VEF",
#                 "targetName": "Venezuelan Bolivar (till 20 August 2018)",
#                 "exchangeRate": "0.263701",
#                 "inverseRate": "3.792173",
#                 "inverseDescription": "1 Venezuelan Bolivar (till 20 August 2018) = 3.792173 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 4.982915 JPY",
#                 "link": "http://www.floatrates.com/czk/jpy/",
#                 "description": "1 Czech Koruna = 4.982915 Japanese Yen",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "JPY",
#                 "targetName": "Japanese Yen",
#                 "exchangeRate": "4.982915",
#                 "inverseRate": "0.200686",
#                 "inverseDescription": "1 Japanese Yen = 0.200686 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.080796 BGN",
#                 "link": "http://www.floatrates.com/czk/bgn/",
#                 "description": "1 Czech Koruna = 0.080796 Bulgarian Lev",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "BGN",
#                 "targetName": "Bulgarian Lev",
#                 "exchangeRate": "0.080796",
#                 "inverseRate": "12.376887",
#                 "inverseDescription": "1 Bulgarian Lev = 12.376887 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.142638 LTL",
#                 "link": "http://www.floatrates.com/czk/ltl/",
#                 "description": "1 Czech Koruna = 0.142638 Lithuanian Litas",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "LTL",
#                 "targetName": "Lithuanian Litas",
#                 "exchangeRate": "0.142638",
#                 "inverseRate": "7.010749",
#                 "inverseDescription": "1 Lithuanian Litas = 7.010749 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.029310 LVL",
#                 "link": "http://www.floatrates.com/czk/lvl/",
#                 "description": "1 Czech Koruna = 0.029310 Latvian Lats",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "LVL",
#                 "targetName": "Latvian Lats",
#                 "exchangeRate": "0.029310",
#                 "inverseRate": "34.117992",
#                 "inverseDescription": "1 Latvian Lats = 34.117992 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.169788 RON",
#                 "link": "http://www.floatrates.com/czk/ron/",
#                 "description": "1 Czech Koruna = 0.169788 Romanian New Leu",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "RON",
#                 "targetName": "Romanian New Leu",
#                 "exchangeRate": "0.169788",
#                 "inverseRate": "5.889712",
#                 "inverseDescription": "1 Romanian New Leu = 5.889712 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.304936 HRK",
#                 "link": "http://www.floatrates.com/czk/hrk/",
#                 "description": "1 Czech Koruna = 0.304936 Croatian Kuna",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "HRK",
#                 "targetName": "Croatian Kuna",
#                 "exchangeRate": "0.304936",
#                 "inverseRate": "3.279376",
#                 "inverseDescription": "1 Croatian Kuna = 3.279376 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.094507 TRY",
#                 "link": "http://www.floatrates.com/czk/try/",
#                 "description": "1 Czech Koruna = 0.094507 Turkish Lira",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "TRY",
#                 "targetName": "Turkish Lira",
#                 "exchangeRate": "0.094507",
#                 "inverseRate": "10.581246",
#                 "inverseDescription": "1 Turkish Lira = 10.581246 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.097407 BRL",
#                 "link": "http://www.floatrates.com/czk/brl/",
#                 "description": "1 Czech Koruna = 0.097407 Brazilian Real",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "BRL",
#                 "targetName": "Brazilian Real",
#                 "exchangeRate": "0.097407",
#                 "inverseRate": "10.266218",
#                 "inverseDescription": "1 Brazilian Real = 10.266218 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.477648 HKD",
#                 "link": "http://www.floatrates.com/czk/hkd/",
#                 "description": "1 Czech Koruna = 0.477648 Hong Kong Dollar",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "HKD",
#                 "targetName": "Hong Kong Dollar",
#                 "exchangeRate": "0.477648",
#                 "inverseRate": "2.093590",
#                 "inverseDescription": "1 Hong Kong Dollar = 2.093590 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 0.711265 MXN",
#                 "link": "http://www.floatrates.com/czk/mxn/",
#                 "description": "1 Czech Koruna = 0.711265 Mexican Peso",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "MXN",
#                 "targetName": "Mexican Peso",
#                 "exchangeRate": "0.711265",
#                 "inverseRate": "1.405945",
#                 "inverseDescription": "1 Mexican Peso = 1.405945 Czech Koruna"
#             },
#             {
#                 "title": "1 CZK = 2.638276 PHP",
#                 "link": "http://www.floatrates.com/czk/php/",
#                 "description": "1 Czech Koruna = 2.638276 Philippine Peso",
#                 "pubDate": null,
#                 "baseCurrency": "CZK",
#                 "baseName": "Czech Koruna",
#                 "targetCurrency": "PHP",
#                 "targetName": "Philippine Peso",
#                 "exchangeRate": "2.638276",
#                 "inverseRate": "0.379035",
#                 "inverseDescription": "1 Philippine Peso = 0.379035 Czech Koruna"
#             }
#         ]
#     }
# }

# %%
#downloader
import requests
import xmltodict
import json
import random
import os
from datetime import datetime
import time

def download_exchange_rates(base_currency, date, target_currency):
    url = f"https://www.floatrates.com/historical-exchange-rates.html?operation=rates&pb_id=1775&page=historical&currency_date={date}&base_currency_code={base_currency}&format_type=xml"
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.text
    except requests.RequestException as e:
        print(f"there was an error downloadeing the data: {e}")
    return None

def parse_xml_to_json(xml_data):
    try:
        data_dict = xmltodict.parse(xml_data)
        json_data = json.dumps(data_dict, indent=4)
        return json_data
    except Exception as e:
        print(f"there was a error parsing the XML data: {e}")
        return None
    return None

# %%
#save.py
import json
import os   
from datetime import datetime

def save_json_to_file(json_data, base_currency, date):
    data_dir=f"data/{base_currency}"
    os.makedirs(data_dir, exist_ok=True)
    timestamp = datetime.now().strftime("%Y%m%d%H%M%S")
    file_name = f"{base_currency}/{date}_{timestamp}.json"
    try:
        with open(file_name,'w')as f:
            f.write(json_data)
            print(f"data saved for {base_currency} on {date} to {file_name}")
    except Exception as e:
        print(f"Error saving data for {base_currency} on {date}: {e}")

# %%
#main.py
import threading
from datetime import date, timedelta
import os
import time
import logging
from downloader import download_exchange_rates, parse_xml_to_json      
from save import save_json_to_file
from queue import Queue

# %% [markdown]
# --------------------------------------------
# # Quest 2 (50 XP): Decipher the scrolls – Exploratory Data Analysis
#
# Once the scrolls have been retrieved their knowledge remains unrefined there patterns hidden, trends veiled. Your task now is to become the Seer of Exchange, the one who can read the currencies’ fates through the lens of data.
# 8
# Perform Exploratory Data Analysis (EDA) on the dataset you collected in Quest 1.
# - Aggregate and visualize trends in exchange rate over time for at least 5 major currencies (e.g., USD, EUR, GBP, JPY, CNY).
#
# - Identify periods of volatility — perhaps during economic upheaval
#
# - Generate at least multiple visualizations using seaborn:
#
# - Log your quest progress in your quest book to show the Grand Master what you learned this is very important. some examples of observations are:
#     - Anomalies, seasonal patterns, or economic events
#     - Currencies with the most/least stability
#     - Any interesting correlations between currencies
#
#
# ## Notes from the Grand Master
# - All of your work in this section should be in your jupyter notebook.
#
# - It might be helpful to use  google to reveal how economic events affected currency. Use Google News or economic calendars to correlate real-world events to exchange rate spikes or dips.

# %% [markdown]
# --------------------------------------------

# %% [markdown]
# # Side Quest 1 (10 XP): Lay Down Seeds for Those Who Follow – Logging
#
# Even the greatest explorer must leave breadcrumbs for those who walk the path after them. Here you will construct an error log system, a journal that captures both triumphs and catastrophes.
#
# Implement a robust logging system throughout your codebase to monitor:
# - Successful currency downloads
# - Parsing attempts and failures
# - Skipped downloads (due to saved data or time out)
# - Connection errors
#
# ## Notes from the Grand Master
# - You do not need to do log hierarchy
# - Use log levels: INFO for progress, WARNING for skips, ERROR for failures

# %% [markdown]
# --------------------------------------------

# %% [markdown]
# # Side Quest 2 (10 XP): The quest of Reflection – Code Profiling
#
# The final challenge for any Adventure is introspection — learning the nature of one's own power. In this side quest, you will profile your code, to discover its bottlenecks, inefficiencies, and optimization opportunities.
#
# Use profiling tools to evaluate:
# - Which functions are taking the most time
# - How threads/processes are behaving
# - Whether I/O is a bottleneck
#
# *A random vendor appears* His invintory shows:
# - A Profiler function - cProfile or Profile
# - A time module - timeit for micro-benchmarks
# - A line profiler - line_profiler
