# %% [markdown]
# ``` py
#
# !pip install takeHomeTest
# import takeHomeTest
#
# !pip install time
# from time import oneWeek as panic
#
# panic.dump(takeHomeTest)
#
#
# print("Welcome to your take home final!\n")
# ```
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## ------------------------------------------- The Legend of Python --------------------------------------------
# **Lore**
#
# In the Kingdom of Pyrovia, all nations once traded in harmony. But since the Shattering of the Global APIs, the knowledge of currency exchange — locked away in XML scrolls — has scattered across the timelines. These scrolls reside in a mysterious repository known only as floatrates.com.
#
# The High Council of Programmers has summoned you (and only you), young code-wielder, to begin your final trial. It is divided into 2 parts.
# * Quest 1 (50xp): Retrieving the scrolls of time - Threading and Json save and parsing
# * Quest 2 (50xp): Decipher the scrolls - Perform EDA on the data.
#
# ------ ------ ------ ------ Extra credit ------ ------ ------ ------
# * Side Quest 1 (10xp*): Lay down seeds for those that follow - create error logs
# * Side Quest 2 (10xp*): The Quest of reflection  - Use profiling on your code to fully understand it
#
# *any points over 100% will be rolled over into your final grade.
#
# I may not have time to run all of your code so make sure you very clearly take notes and communicate successes, issues, and lessons learned.
# Please stay off Chat GPT and stack overflow (and like). You should have most everything you need in the notes.

# %% [markdown]
# --------------------------------------------
# # Quest 1 (50 xp): Retrieving the Scrolls of Time
# Retrieve historical exchange rate data from floatrates.com for one of the (Ideally randomly pick) 52 available currencies, starting from the first record on May 4, 2011, until the present day.
#
# - You may store the data as-is in XML, or convert it to JSON, you may use the supplied code below as a starter.
#
# - Organize each currency into its own directory.
#
# - Ensure your code is modular, maintainable, and robust against timeouts or malformed entries.
#
# ## Notes from the Grand Master
# * Threading is your ally. But do not burn out your ally as they have limited resources. You may use the threading or multi-core to parallelize downloads — but mind the server’s load. Around 10 threads is wise.
#     - You should have around 5040 queries.
#
# * XML Scrolls is a new and unfamiliar beast. Therefore takeing on this beast will wield 5 extra experience points. You will not be penalized for choosing to use JSON
#
# *  Use the Save. Nothing is worse than losing experience you have already gained. Save the raw XML (or converted JSON) using timestamped (in my example below) files so you do not need to look it up again. Ie. If you put in a start date and your program has already read that data it should not pull that date again. (it would be a good idea to delete your data and run it top to bottom before final submission)
#
# * Design gracefully. Structure your project with clear modules: downloader.py, parser.py, and so on.
#
# * Log your quest progress in your quest book to show the Grand Master what you learned this is very important.

# %% [markdown]
# --------------------------------------------

# %%
# !pip install xmltodict
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\rvsoe\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: xmltodict in c:\users\rvsoe\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (0.14.2)

# %%
rates = ["EUR", "GBP", "USD", "DZD", "AUD", "BWP", "BND", "CAD", "CLP", "CNY", "COP", "CZK", "DKK", "HUF", "ISK", "INR", "IDR", "ILS", "KZT", "KRW", "KWD", "LYD", "MYR", "MUR", "NPR", "NZD", "NOK", "OMR", "PKR", "PLN", "QAR", "RUB", "SAR", "SGD", "ZAR", "LKR", "SEK", "CHF", "THB", "TTD"]
ratesForBase = [r for r in rates if r != "USD" and r != "EUR" and r != "GBP"]

# %%
import requests
import xmltodict
import json
import random

# URL of the XML data
date = "2011-05-04"
base = random.choice(ratesForBase)
url = f"https://www.floatrates.com/historical-exchange-rates.html?operation=rates&pb_id=1775&page=historical&currency_date={date}&base_currency_code={base}&format_type=xml"
print(url)
# Fetch the XML data
response = requests.get(url)
response.raise_for_status()  # Ensure we notice bad responses

# Parse the XML data to a Python dictionary
data_dict = xmltodict.parse(response.text)

# Convert the dictionary to a JSON string
json_data = json.dumps(data_dict, indent=4)

# Print the JSON data
print(json_data)

# Optionally, write the JSON data to a file
with open(f"{date}_exchange_rates_{base}.json", "w") as json_file:
    json_file.write(json_data)
# Out:
# https://www.floatrates.com/historical-exchange-rates.html?operation=rates&pb_id=1775&page=historical&currency_date=2011-05-04&base_currency_code=DZD&format_type=xml
# {
#     "channel": {
#         "title": "XML Historical Foreign Exchange Rates for Algerian Dinar (DZD) (4 May 2011)",
#         "link": "http://www.floatrates.com/currency/dzd/",
#         "xmlLink": "http://www.floatrates.com/daily/dzd.xml",
#         "description": "XML historical foreign exchange rates for Algerian Dinar (DZD) from the Float Rates. Published at 4 May 2011.",
#         "language": "en",
#         "baseCurrency": "DZD",
#         "pubDate": "Wed, 4 May 2011",
#         "lastBuildDate": "Wed, 4 May 2011",
#         "item": [
#             {
#                 "title": "1 DZD = 0.009425 EUR",
#                 "link": "http://www.floatrates.com/dzd/eur/",
#                 "description": "1 Algerian Dinar = 0.009425 Euro",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "EUR",
#                 "targetName": "Euro",
#                 "exchangeRate": "0.009425",
#                 "inverseRate": "106.098243",
#                 "inverseDescription": "1 Euro = 106.098243 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.008490 GBP",
#                 "link": "http://www.floatrates.com/dzd/gbp/",
#                 "description": "1 Algerian Dinar = 0.008490 U.K. Pound Sterling",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "GBP",
#                 "targetName": "U.K. Pound Sterling",
#                 "exchangeRate": "0.008490",
#                 "inverseRate": "117.779284",
#                 "inverseDescription": "1 U.K. Pound Sterling = 117.779284 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.014027 USD",
#                 "link": "http://www.floatrates.com/dzd/usd/",
#                 "description": "1 Algerian Dinar = 0.014027 U.S. Dollar",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "USD",
#                 "targetName": "U.S. Dollar",
#                 "exchangeRate": "0.014027",
#                 "inverseRate": "71.293000",
#                 "inverseDescription": "1 U.S. Dollar = 71.293000 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 1.000000 DZD",
#                 "link": "http://www.floatrates.com/dzd/dzd/",
#                 "description": "1 Algerian Dinar = 1.000000 Algerian Dinar",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "DZD",
#                 "targetName": "Algerian Dinar",
#                 "exchangeRate": "1.000000",
#                 "inverseRate": "1.000000",
#                 "inverseDescription": "1 Algerian Dinar = 1.000000 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.012948 AUD",
#                 "link": "http://www.floatrates.com/dzd/aud/",
#                 "description": "1 Algerian Dinar = 0.012948 Australian Dollar",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "AUD",
#                 "targetName": "Australian Dollar",
#                 "exchangeRate": "0.012948",
#                 "inverseRate": "77.232653",
#                 "inverseDescription": "1 Australian Dollar = 77.232653 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.089398 BWP",
#                 "link": "http://www.floatrates.com/dzd/bwp/",
#                 "description": "1 Algerian Dinar = 0.089398 Botswana Pula",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "BWP",
#                 "targetName": "Botswana Pula",
#                 "exchangeRate": "0.089398",
#                 "inverseRate": "11.185872",
#                 "inverseDescription": "1 Botswana Pula = 11.185872 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.017256 BND",
#                 "link": "http://www.floatrates.com/dzd/bnd/",
#                 "description": "1 Algerian Dinar = 0.017256 Brunei Dollar",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "BND",
#                 "targetName": "Brunei Dollar",
#                 "exchangeRate": "0.017256",
#                 "inverseRate": "57.952365",
#                 "inverseDescription": "1 Brunei Dollar = 57.952365 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.013412 CAD",
#                 "link": "http://www.floatrates.com/dzd/cad/",
#                 "description": "1 Algerian Dinar = 0.013412 Canadian Dollar",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "CAD",
#                 "targetName": "Canadian Dollar",
#                 "exchangeRate": "0.013412",
#                 "inverseRate": "74.561452",
#                 "inverseDescription": "1 Canadian Dollar = 74.561452 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 6.495308 CLP",
#                 "link": "http://www.floatrates.com/dzd/clp/",
#                 "description": "1 Algerian Dinar = 6.495308 Chilean Peso",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "CLP",
#                 "targetName": "Chilean Peso",
#                 "exchangeRate": "6.495308",
#                 "inverseRate": "0.153957",
#                 "inverseDescription": "1 Chilean Peso = 0.153957 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.091155 CNY",
#                 "link": "http://www.floatrates.com/dzd/cny/",
#                 "description": "1 Algerian Dinar = 0.091155 Chinese Yuan",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "CNY",
#                 "targetName": "Chinese Yuan",
#                 "exchangeRate": "0.091155",
#                 "inverseRate": "10.970358",
#                 "inverseDescription": "1 Chinese Yuan = 10.970358 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 24.785743 COP",
#                 "link": "http://www.floatrates.com/dzd/cop/",
#                 "description": "1 Algerian Dinar = 24.785743 Colombian Peso",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "COP",
#                 "targetName": "Colombian Peso",
#                 "exchangeRate": "24.785743",
#                 "inverseRate": "0.040346",
#                 "inverseDescription": "1 Colombian Peso = 0.040346 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.228154 CZK",
#                 "link": "http://www.floatrates.com/dzd/czk/",
#                 "description": "1 Algerian Dinar = 0.228154 Czech Koruna",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "CZK",
#                 "targetName": "Czech Koruna",
#                 "exchangeRate": "0.228154",
#                 "inverseRate": "4.383009",
#                 "inverseDescription": "1 Czech Koruna = 4.383009 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.070282 DKK",
#                 "link": "http://www.floatrates.com/dzd/dkk/",
#                 "description": "1 Algerian Dinar = 0.070282 Danish Krone",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "DKK",
#                 "targetName": "Danish Krone",
#                 "exchangeRate": "0.070282",
#                 "inverseRate": "14.228420",
#                 "inverseDescription": "1 Danish Krone = 14.228420 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 2.501379 HUF",
#                 "link": "http://www.floatrates.com/dzd/huf/",
#                 "description": "1 Algerian Dinar = 2.501379 Hungarian Forint",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "HUF",
#                 "targetName": "Hungarian Forint",
#                 "exchangeRate": "2.501379",
#                 "inverseRate": "0.399779",
#                 "inverseDescription": "1 Hungarian Forint = 0.399779 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 1.562425 ISK",
#                 "link": "http://www.floatrates.com/dzd/isk/",
#                 "description": "1 Algerian Dinar = 1.562425 Icelandic Krona",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "ISK",
#                 "targetName": "Icelandic Krona",
#                 "exchangeRate": "1.562425",
#                 "inverseRate": "0.640031",
#                 "inverseDescription": "1 Icelandic Krona = 0.640031 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.624885 INR",
#                 "link": "http://www.floatrates.com/dzd/inr/",
#                 "description": "1 Algerian Dinar = 0.624885 Indian Rupee",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "INR",
#                 "targetName": "Indian Rupee",
#                 "exchangeRate": "0.624885",
#                 "inverseRate": "1.600294",
#                 "inverseDescription": "1 Indian Rupee = 1.600294 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 120.021051 IDR",
#                 "link": "http://www.floatrates.com/dzd/idr/",
#                 "description": "1 Algerian Dinar = 120.021051 Indonesian Rupiah",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "IDR",
#                 "targetName": "Indonesian Rupiah",
#                 "exchangeRate": "120.021051",
#                 "inverseRate": "0.008332",
#                 "inverseDescription": "1 Indonesian Rupiah = 0.008332 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.047589 ILS",
#                 "link": "http://www.floatrates.com/dzd/ils/",
#                 "description": "1 Algerian Dinar = 0.047589 Israeli New Sheqel",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "ILS",
#                 "targetName": "Israeli New Sheqel",
#                 "exchangeRate": "0.047589",
#                 "inverseRate": "21.013092",
#                 "inverseDescription": "1 Israeli New Sheqel = 21.013092 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 2.044941 KZT",
#                 "link": "http://www.floatrates.com/dzd/kzt/",
#                 "description": "1 Algerian Dinar = 2.044941 Kazakhstani Tenge",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "KZT",
#                 "targetName": "Kazakhstani Tenge",
#                 "exchangeRate": "2.044941",
#                 "inverseRate": "0.489012",
#                 "inverseDescription": "1 Kazakhstani Tenge = 0.489012 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 15.023256 KRW",
#                 "link": "http://www.floatrates.com/dzd/krw/",
#                 "description": "1 Algerian Dinar = 15.023256 South Korean Won",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "KRW",
#                 "targetName": "South Korean Won",
#                 "exchangeRate": "15.023256",
#                 "inverseRate": "0.066563",
#                 "inverseDescription": "1 South Korean Won = 0.066563 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.003849 KWD",
#                 "link": "http://www.floatrates.com/dzd/kwd/",
#                 "description": "1 Algerian Dinar = 0.003849 Kuwaiti Dinar",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "KWD",
#                 "targetName": "Kuwaiti Dinar",
#                 "exchangeRate": "0.003849",
#                 "inverseRate": "259.814140",
#                 "inverseDescription": "1 Kuwaiti Dinar = 259.814140 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.027105 LYD",
#                 "link": "http://www.floatrates.com/dzd/lyd/",
#                 "description": "1 Algerian Dinar = 0.027105 Libyan Dinar",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "LYD",
#                 "targetName": "Libyan Dinar",
#                 "exchangeRate": "0.027105",
#                 "inverseRate": "36.893500",
#                 "inverseDescription": "1 Libyan Dinar = 36.893500 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.041785 MYR",
#                 "link": "http://www.floatrates.com/dzd/myr/",
#                 "description": "1 Algerian Dinar = 0.041785 Malaysian Ringgit",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "MYR",
#                 "targetName": "Malaysian Ringgit",
#                 "exchangeRate": "0.041785",
#                 "inverseRate": "23.931805",
#                 "inverseDescription": "1 Malaysian Ringgit = 23.931805 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.381924 MUR",
#                 "link": "http://www.floatrates.com/dzd/mur/",
#                 "description": "1 Algerian Dinar = 0.381924 Mauritian Rupee",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "MUR",
#                 "targetName": "Mauritian Rupee",
#                 "exchangeRate": "0.381924",
#                 "inverseRate": "2.618323",
#                 "inverseDescription": "1 Mauritian Rupee = 2.618323 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.997854 NPR",
#                 "link": "http://www.floatrates.com/dzd/npr/",
#                 "description": "1 Algerian Dinar = 0.997854 Nepalese Rupee",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "NPR",
#                 "targetName": "Nepalese Rupee",
#                 "exchangeRate": "0.997854",
#                 "inverseRate": "1.002151",
#                 "inverseDescription": "1 Nepalese Rupee = 1.002151 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.017605 NZD",
#                 "link": "http://www.floatrates.com/dzd/nzd/",
#                 "description": "1 Algerian Dinar = 0.017605 New Zealand Dollar",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "NZD",
#                 "targetName": "New Zealand Dollar",
#                 "exchangeRate": "0.017605",
#                 "inverseRate": "56.801598",
#                 "inverseDescription": "1 New Zealand Dollar = 56.801598 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.074186 NOK",
#                 "link": "http://www.floatrates.com/dzd/nok/",
#                 "description": "1 Algerian Dinar = 0.074186 Norwegian Krone",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "NOK",
#                 "targetName": "Norwegian Krone",
#                 "exchangeRate": "0.074186",
#                 "inverseRate": "13.479707",
#                 "inverseDescription": "1 Norwegian Krone = 13.479707 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.005393 OMR",
#                 "link": "http://www.floatrates.com/dzd/omr/",
#                 "description": "1 Algerian Dinar = 0.005393 Omani Rial",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "OMR",
#                 "targetName": "Omani Rial",
#                 "exchangeRate": "0.005393",
#                 "inverseRate": "185.417425",
#                 "inverseDescription": "1 Omani Rial = 185.417425 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 1.182564 PKR",
#                 "link": "http://www.floatrates.com/dzd/pkr/",
#                 "description": "1 Algerian Dinar = 1.182564 Pakistani Rupee",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "PKR",
#                 "targetName": "Pakistani Rupee",
#                 "exchangeRate": "1.182564",
#                 "inverseRate": "0.845621",
#                 "inverseDescription": "1 Pakistani Rupee = 0.845621 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.037147 PLN",
#                 "link": "http://www.floatrates.com/dzd/pln/",
#                 "description": "1 Algerian Dinar = 0.037147 Polish Zloty",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "PLN",
#                 "targetName": "Polish Zloty",
#                 "exchangeRate": "0.037147",
#                 "inverseRate": "26.919919",
#                 "inverseDescription": "1 Polish Zloty = 26.919919 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.051057 QAR",
#                 "link": "http://www.floatrates.com/dzd/qar/",
#                 "description": "1 Algerian Dinar = 0.051057 Qatari Rial",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "QAR",
#                 "targetName": "Qatari Rial",
#                 "exchangeRate": "0.051057",
#                 "inverseRate": "19.585989",
#                 "inverseDescription": "1 Qatari Rial = 19.585989 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.383251 RUB",
#                 "link": "http://www.floatrates.com/dzd/rub/",
#                 "description": "1 Algerian Dinar = 0.383251 Russian Rouble",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "RUB",
#                 "targetName": "Russian Rouble",
#                 "exchangeRate": "0.383251",
#                 "inverseRate": "2.609259",
#                 "inverseDescription": "1 Russian Rouble = 2.609259 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.052600 SAR",
#                 "link": "http://www.floatrates.com/dzd/sar/",
#                 "description": "1 Algerian Dinar = 0.052600 Saudi Riyal",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "SAR",
#                 "targetName": "Saudi Riyal",
#                 "exchangeRate": "0.052600",
#                 "inverseRate": "19.011467",
#                 "inverseDescription": "1 Saudi Riyal = 19.011467 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.017242 SGD",
#                 "link": "http://www.floatrates.com/dzd/sgd/",
#                 "description": "1 Algerian Dinar = 0.017242 Singapore Dollar",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "SGD",
#                 "targetName": "Singapore Dollar",
#                 "exchangeRate": "0.017242",
#                 "inverseRate": "57.997599",
#                 "inverseDescription": "1 Singapore Dollar = 57.997599 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.092911 ZAR",
#                 "link": "http://www.floatrates.com/dzd/zar/",
#                 "description": "1 Algerian Dinar = 0.092911 South African Rand",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "ZAR",
#                 "targetName": "South African Rand",
#                 "exchangeRate": "0.092911",
#                 "inverseRate": "10.762976",
#                 "inverseDescription": "1 South African Rand = 10.762976 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 1.539864 LKR",
#                 "link": "http://www.floatrates.com/dzd/lkr/",
#                 "description": "1 Algerian Dinar = 1.539864 Sri Lanka Rupee",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "LKR",
#                 "targetName": "Sri Lanka Rupee",
#                 "exchangeRate": "1.539864",
#                 "inverseRate": "0.649408",
#                 "inverseDescription": "1 Sri Lanka Rupee = 0.649408 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.084766 SEK",
#                 "link": "http://www.floatrates.com/dzd/sek/",
#                 "description": "1 Algerian Dinar = 0.084766 Swedish Krona",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "SEK",
#                 "targetName": "Swedish Krona",
#                 "exchangeRate": "0.084766",
#                 "inverseRate": "11.797207",
#                 "inverseDescription": "1 Swedish Krona = 11.797207 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.012094 CHF",
#                 "link": "http://www.floatrates.com/dzd/chf/",
#                 "description": "1 Algerian Dinar = 0.012094 Swiss Franc",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "CHF",
#                 "targetName": "Swiss Franc",
#                 "exchangeRate": "0.012094",
#                 "inverseRate": "82.685824",
#                 "inverseDescription": "1 Swiss Franc = 82.685824 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.421134 THB",
#                 "link": "http://www.floatrates.com/dzd/thb/",
#                 "description": "1 Algerian Dinar = 0.421134 Thai Baht",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "THB",
#                 "targetName": "Thai Baht",
#                 "exchangeRate": "0.421134",
#                 "inverseRate": "2.374540",
#                 "inverseDescription": "1 Thai Baht = 2.374540 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.089702 TTD",
#                 "link": "http://www.floatrates.com/dzd/ttd/",
#                 "description": "1 Algerian Dinar = 0.089702 Trinidad Tobago Dollar",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "TTD",
#                 "targetName": "Trinidad Tobago Dollar",
#                 "exchangeRate": "0.089702",
#                 "inverseRate": "11.148066",
#                 "inverseDescription": "1 Trinidad Tobago Dollar = 11.148066 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.051513 AED",
#                 "link": "http://www.floatrates.com/dzd/aed/",
#                 "description": "1 Algerian Dinar = 0.051513 U.A.E Dirham",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "AED",
#                 "targetName": "U.A.E Dirham",
#                 "exchangeRate": "0.051513",
#                 "inverseRate": "19.412662",
#                 "inverseDescription": "1 U.A.E Dirham = 19.412662 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.060164 VEF",
#                 "link": "http://www.floatrates.com/dzd/vef/",
#                 "description": "1 Algerian Dinar = 0.060164 Venezuelan Bolivar (till 20 August 2018)",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "VEF",
#                 "targetName": "Venezuelan Bolivar (till 20 August 2018)",
#                 "exchangeRate": "0.060164",
#                 "inverseRate": "16.621127",
#                 "inverseDescription": "1 Venezuelan Bolivar (till 20 August 2018) = 16.621127 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 1.136871 JPY",
#                 "link": "http://www.floatrates.com/dzd/jpy/",
#                 "description": "1 Algerian Dinar = 1.136871 Japanese Yen",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "JPY",
#                 "targetName": "Japanese Yen",
#                 "exchangeRate": "1.136871",
#                 "inverseRate": "0.879607",
#                 "inverseDescription": "1 Japanese Yen = 0.879607 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.018434 BGN",
#                 "link": "http://www.floatrates.com/dzd/bgn/",
#                 "description": "1 Algerian Dinar = 0.018434 Bulgarian Lev",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "BGN",
#                 "targetName": "Bulgarian Lev",
#                 "exchangeRate": "0.018434",
#                 "inverseRate": "54.248002",
#                 "inverseDescription": "1 Bulgarian Lev = 54.248002 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.032543 LTL",
#                 "link": "http://www.floatrates.com/dzd/ltl/",
#                 "description": "1 Algerian Dinar = 0.032543 Lithuanian Litas",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "LTL",
#                 "targetName": "Lithuanian Litas",
#                 "exchangeRate": "0.032543",
#                 "inverseRate": "30.728175",
#                 "inverseDescription": "1 Lithuanian Litas = 30.728175 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.006687 LVL",
#                 "link": "http://www.floatrates.com/dzd/lvl/",
#                 "description": "1 Algerian Dinar = 0.006687 Latvian Lats",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "LVL",
#                 "targetName": "Latvian Lats",
#                 "exchangeRate": "0.006687",
#                 "inverseRate": "149.539454",
#                 "inverseDescription": "1 Latvian Lats = 149.539454 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.038738 RON",
#                 "link": "http://www.floatrates.com/dzd/ron/",
#                 "description": "1 Algerian Dinar = 0.038738 Romanian New Leu",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "RON",
#                 "targetName": "Romanian New Leu",
#                 "exchangeRate": "0.038738",
#                 "inverseRate": "25.814658",
#                 "inverseDescription": "1 Romanian New Leu = 25.814658 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.069572 HRK",
#                 "link": "http://www.floatrates.com/dzd/hrk/",
#                 "description": "1 Algerian Dinar = 0.069572 Croatian Kuna",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "HRK",
#                 "targetName": "Croatian Kuna",
#                 "exchangeRate": "0.069572",
#                 "inverseRate": "14.373534",
#                 "inverseDescription": "1 Croatian Kuna = 14.373534 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.021562 TRY",
#                 "link": "http://www.floatrates.com/dzd/try/",
#                 "description": "1 Algerian Dinar = 0.021562 Turkish Lira",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "TRY",
#                 "targetName": "Turkish Lira",
#                 "exchangeRate": "0.021562",
#                 "inverseRate": "46.377691",
#                 "inverseDescription": "1 Turkish Lira = 46.377691 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.022224 BRL",
#                 "link": "http://www.floatrates.com/dzd/brl/",
#                 "description": "1 Algerian Dinar = 0.022224 Brazilian Real",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "BRL",
#                 "targetName": "Brazilian Real",
#                 "exchangeRate": "0.022224",
#                 "inverseRate": "44.996922",
#                 "inverseDescription": "1 Brazilian Real = 44.996922 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.108977 HKD",
#                 "link": "http://www.floatrates.com/dzd/hkd/",
#                 "description": "1 Algerian Dinar = 0.108977 Hong Kong Dollar",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "HKD",
#                 "targetName": "Hong Kong Dollar",
#                 "exchangeRate": "0.108977",
#                 "inverseRate": "9.176223",
#                 "inverseDescription": "1 Hong Kong Dollar = 9.176223 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.162278 MXN",
#                 "link": "http://www.floatrates.com/dzd/mxn/",
#                 "description": "1 Algerian Dinar = 0.162278 Mexican Peso",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "MXN",
#                 "targetName": "Mexican Peso",
#                 "exchangeRate": "0.162278",
#                 "inverseRate": "6.162269",
#                 "inverseDescription": "1 Mexican Peso = 6.162269 Algerian Dinar"
#             },
#             {
#                 "title": "1 DZD = 0.601933 PHP",
#                 "link": "http://www.floatrates.com/dzd/php/",
#                 "description": "1 Algerian Dinar = 0.601933 Philippine Peso",
#                 "pubDate": null,
#                 "baseCurrency": "DZD",
#                 "baseName": "Algerian Dinar",
#                 "targetCurrency": "PHP",
#                 "targetName": "Philippine Peso",
#                 "exchangeRate": "0.601933",
#                 "inverseRate": "1.661315",
#                 "inverseDescription": "1 Philippine Peso = 1.661315 Algerian Dinar"
#             }
#         ]
#     }
# }

# %% [markdown]
# --------------------------------------------
# # Quest 2 (50 XP): Decipher the scrolls – Exploratory Data Analysis
#
# Once the scrolls have been retrieved their knowledge remains unrefined there patterns hidden, trends veiled. Your task now is to become the Seer of Exchange, the one who can read the currencies’ fates through the lens of data.
# 8
# Perform Exploratory Data Analysis (EDA) on the dataset you collected in Quest 1.
# - Aggregate and visualize trends in exchange rate over time for at least 5 major currencies (e.g., USD, EUR, GBP, JPY, CNY).
#
# - Identify periods of volatility — perhaps during economic upheaval
#
# - Generate at least multiple visualizations using seaborn:
#
# - Log your quest progress in your quest book to show the Grand Master what you learned this is very important. some examples of observations are:
#     - Anomalies, seasonal patterns, or economic events
#     - Currencies with the most/least stability
#     - Any interesting correlations between currencies
#
#
# ## Notes from the Grand Master
# - All of your work in this section should be in your jupyter notebook.
#
# - It might be helpful to use  google to reveal how economic events affected currency. Use Google News or economic calendars to correlate real-world events to exchange rate spikes or dips.

# %% [markdown]
# --------------------------------------------

# %%
import pandas as pd
import matplotlib.pyplot as plt
import json
import os
from datetime import datetime 

DATA_DIR = "data_random"
!
currency_data = {}
for filename in os.listdir(DATA_DIR):  
    if filename.endswith(".json"):
        currency = filename.replace(".json", "")
        filepath = os.path.join(DATA_DIR, filename) 
        with open(filepath, "r") as f:
            currency_data[currency] = json.load(f)

# %% [markdown]
# # Side Quest 1 (10 XP): Lay Down Seeds for Those Who Follow – Logging
#
# Even the greatest explorer must leave breadcrumbs for those who walk the path after them. Here you will construct an error log system, a journal that captures both triumphs and catastrophes.
#
# Implement a robust logging system throughout your codebase to monitor:
# - Successful currency downloads
# - Parsing attempts and failures
# - Skipped downloads (due to saved data or time out)
# - Connection errors
#
# ## Notes from the Grand Master
# - You do not need to do log hierarchy
# - Use log levels: INFO for progress, WARNING for skips, ERROR for failures

# %% [markdown]
# --------------------------------------------

# %% [markdown]
# # Side Quest 2 (10 XP): The quest of Reflection – Code Profiling
#
# The final challenge for any Adventure is introspection — learning the nature of one's own power. In this side quest, you will profile your code, to discover its bottlenecks, inefficiencies, and optimization opportunities.
#
# Use profiling tools to evaluate:
# - Which functions are taking the most time
# - How threads/processes are behaving
# - Whether I/O is a bottleneck
#
# *A random vendor appears* His invintory shows:
# - A Profiler function - cProfile or Profile
# - A time module - timeit for micro-benchmarks
# - A line profiler - line_profiler
